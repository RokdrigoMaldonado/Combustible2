# %%
from sqlalchemy import Column, Integer, String,Boolean, ForeignKey,UniqueConstraint,PrimaryKeyConstraint,sql
from sqlalchemy.orm import declarative_base,sessionmaker,relationship,configure_mappers
from sqlalchemy.inspection import inspect
from sqlalchemy import *
from sqlalchemy import event,Sequence,Identity
import pandas as pd
import os
import fnmatch
import re
import multiprocessing as mp
import xlrd
import pickle
import time
from readExcelFiles import *
from queryblock import *
from MultiORM import *
from openpyxl import load_workbook
from functools import partial

path_engine = "firebird://sysdba:300184rm2@206.81.11.212///var/lib/firebird/3.0/data/SensoresRomaga.fdb"
path_to_files="/home/rokdrigo/GitClone/Combustible2/Sensores/"

#host='206.81.11.212/var/lib/firebird/3.0/data/RomagaFacturasxml.fdb'
#user='sysdba'
#password='300184rm2'

engine = create_engine(path_engine, echo=False, future=False)

Base = declarative_base()

class Sensores(Base):
    
    __tablename__='Sensores_table'
    __table_args__ = (
    #this can be db.PrimaryKeyConstraint if you want it to be a primary key
    PrimaryKeyConstraint('Fecha_Hora', 'unidad_id', name='id_mix'),)
    Fecha_Hora=Column('Fecha_Hora', TIMESTAMP)
    Tanque1=Column('Tanque 1 (Lt)', Integer, nullable=True)
    Tanque2= Column('Tanque 2 (Lt)', Integer, nullable=True)
    Odómetro=Column('Odómetro (Km)', Integer, nullable=True)
    file_name= Column('file_name', String(1024), nullable=True)
    file=Column('file', String(1024), nullable=True)
    unidad_id = Column(Numeric, ForeignKey('Unidades.numero'))
    unidad = relationship("Unidad", back_populates="sensoresUbica")
    

class SensoresCanbus(Base):
    
    __tablename__='Sensores_canbus'
    __table_args__ = (
        # this can be db.PrimaryKeyConstraint if you want it to be a primary key
        PrimaryKeyConstraint('Fecha_Hora', 'unidad_id'),
    )
    Fecha_Hora=Column('Fecha_Hora',TIMESTAMP)
    canbus=Column('Total de Combustible', Integer, nullable=True)
    temp= Column('Temperatura del motor °C ', Integer, nullable=True)
    rpm=Column('Velocidad del Motor (RPM)', Integer, nullable=True)
    Odometro=Column('Odómetro (Km)', Integer, nullable=True)
    file_name= Column('file_name', String(1024), nullable=True)
    file= Column( 'file',String(1024),nullable=True)
    unidad_id = Column(Numeric, ForeignKey('Unidades.numero'))
    unidad_can = relationship("Unidad", back_populates="sensoresCanUbica")
    
class Unidad(Base):
    
    __tablename__ = 'Unidades'

    #id = Column(Integer,nullable=False,primary_key=True)
    numero = Column(Integer,primary_key=True)
    economico=Column(String(256),unique=True)
    canbus = Column(String(256))
    company = Column(String(256))
    sensoresUbica = relationship("Sensores",back_populates="unidad")
    sensoresCanUbica = relationship("SensoresCanbus",back_populates="unidad_can")
    
    def __init__(self,numero,economico,canbus,company):
        self.numero=numero
        self.economico = economico
        self.canbus=canbus
        self.company = company
        #self.parsedFiles=[]
    
    def __str__(self):
        return "La unidad:"+str(self.numero)+" "+"Compania"+" "+str(self.company)
    
    
    def get_files(self):
        
        self.ListFilesUnidad=[]
        self.Litros_ubicalo=[]
        self.Litros_sacmamx=[]
        self.Canbus_ubicalo=[]
        self.Canbus_sacmamx=[]
        
        os.chdir(path_to_files)
        
        loadeded_litros=[item[0] for item in session.query(Sensores.file_name).group_by(Sensores.file_name).all()]
        loadeded_canbus=[item[0] for item in session.query(SensoresCanbus.file_name).group_by(SensoresCanbus.file_name).all()]
        
        ListFilesLoad=([file for file in os.listdir('.') if fnmatch.fnmatch(file, '*.xlsx') or fnmatch.fnmatch(file,'*.csv')])
        ListFilesUnidad=([file for file in ListFilesLoad if re.search(self.economico,file)])
        
        for file in ListFilesUnidad:
            if fnmatch.fnmatch(file, '*.xlsx'):
                
                sheets=get_sheetnames_xlsx(path_to_files+file)
                
                if file not in loadeded_litros:
                    #print(loadeded_litros)
                    print('file in eventos {}'.format(file))
                    if ('Eventos' in sheets) or ('Detalle del Evento' in sheets):
                        print("Eventos")
                        self.Litros_ubicalo.append(file)
                        print(file)
                
                if file not in loadeded_canbus:
                    #print(loadeded_canbus)
                    print('Not file in {}'.format(file))
                    if ('Datos Computadora CAN-BUS OBD' in sheets):
                        print("Canbus")
                        self.Canbus_ubicalo.append(file)
                        
            if file not in loadeded_canbus:
                if fnmatch.fnmatch(file,'*.csv') and re.search('Canbus',file):
                    print("Scama_canbus___{}".format(file))
                    self.Canbus_sacmamx.append(file)                
            
            if file not in loadeded_litros:        
                if fnmatch.fnmatch(file,'*.csv') and not re.search('Canbus',file):
                    print("Sacma fie {}".format(file))
                    self.Litros_sacmamx.append(file)   

        return self.ListFilesUnidad
        
    
    def parse_files(self):
        parsed_files=dict()
        evenots=[]
        Detalle_ubicalo=pd.DataFrame()
        litros_sacmamx=pd.DataFrame()
        canbus_sacmamx=pd.DataFrame()
        Canbus_ubicalo=pd.DataFrame()
        
        
        if self.Litros_ubicalo or self.Litros_sacmamx or self.Canbus_sacmamx or self.Canbus_ubicalo:
            Canbus_ubicalo=[]
            #print(self.Litros_ubicalo)
            cores=3
            print('parse')
            
            map_send=[path_to_files+file for file in  self.Litros_ubicalo]
            if map_send:
                #process_files(cores,map_send,unidad,functionLoad,sheet_load)
                evenots=process_files(cores,map_send,self.numero,loadFiles_litros,sheet_load='Eventos')
            
            map_send=[path_to_files+file for file in self.Canbus_ubicalo]
            if map_send and self.Canbus_ubicalo:
                Canbus_ubicalo=process_files(cores,map_send,self.numero,loadFiles_canbus,sheet_load='Datos Computadora CAN-BUS OBD')
            
            map_send=[path_to_files+file for file in self.Litros_ubicalo]
            if map_send:
                Detalle_ubicalo=process_files(cores,map_send,self.numero,loadFiles_tanques,sheet_load='Detalle del Evento')
                
            map_send=[path_to_files+file for file in self.Canbus_sacmamx]
            if map_send:
                canbus_sacmamx=process_files(cores,map_send,self.numero,load_sacmax_canbus,sheet_load='file canbus sacma not need sheet')
                print('Debug check this to seee what happen {}'.format(map_send))
            
            map_send=[path_to_files+file for file in self.Litros_sacmamx]
            if map_send:
                litros_sacmamx=process_files(cores,map_send,self.numero,load_sacmax_sensores,sheet_load='tanques sacma not need sheet')
              
            print("end load files")
                
            if self.company=='Ubicalo':
                parsed_files= {'Eventos':evenots,'Canbus CAN-BUS':Canbus_ubicalo,'Detalle':Detalle_ubicalo}
                return parsed_files 
          
            if self.company=='Sacmamx':
                parsed_files={'Litros':litros_sacmamx,'Canbus CAN-BUS Sacmamx':canbus_sacmamx}
                return parsed_files
        else:
            print('Nothing')

Base.metadata.create_all(engine)

Index('DateUnidad', Sensores.unidad_id, Sensores.Fecha_Hora, unique=True)

def get_sheetnames_xlsx(filepath):
    wb = load_workbook(filepath, read_only=True, keep_links=False)
    print(wb)
    return wb.sheetnames

def process_files(cores,map_send,unidad,functionLoad,sheet_load):
    with mp.Pool(processes=cores) as pool:
        DatframeList=pool.map(functionLoad,map_send)
    if DatframeList:
        Dataframes_procesados=pd.concat(DatframeList)
        Dataframes_procesados['unidad_id']=unidad
        Dataframes_procesados.sort_values(by=[Dataframes_procesados.columns[0]], inplace=True, ascending=True)
        Dataframes_procesados.drop_duplicates(subset=Dataframes_procesados.columns[0], keep='last',inplace=True)
        return Dataframes_procesados
    else:
        print("Empty Dataframe nothing to concatenate {}".format(sheet_load))
        
configure_mappers()

# %%
#load_dataframe_litros(files_parsed)
path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"

engine = create_engine(path_engine, echo=False, future=False)

Session = sessionmaker(bind=engine)
session = Session()

for item in session.query(SensoresCanbus).all():
    print(item.file)

# %%
#path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"

engine = create_engine(path_engine, echo=False, future=False)

Session = sessionmaker(bind=engine)
session = Session()

Unidades=[]

Unidades.append(Unidad(numero='01', economico ='Eco01',canbus =  False, company = 'Ubicalo'))
Unidades.append(Unidad(numero='05', economico ='Eco05',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='07', economico ='Eco07',canbus =  True, company = 'Sacmamx'))
Unidades.append(Unidad(numero='08', economico ='Eco08',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='09', economico ='Eco09',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='10', economico ='Eco10',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='11', economico ='Eco11',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='12', economico ='Eco12',canbus =  False, company = 'Ubicalo'))
Unidades.append(Unidad(numero='13', economico ='Eco13',canbus =  False, company = 'Ubicalo'))
Unidades.append(Unidad(numero='14', economico ='Eco14',canbus =  True, company = 'Sacmamx'))
Unidades.append(Unidad(numero='15', economico ='Eco15',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='16', economico ='Eco16',canbus =  True, company = 'Ubicalo'))
Unidades.append(Unidad(numero='17', economico ='Eco17',canbus =  False, company = 'Ubicalo'))
Unidades.append(Unidad(numero='18', economico ='Eco18',canbus =  True, company = 'Sacmamx'))

unidad_in = [unidad_in.numero for unidad_in in session.query(Unidad).all()]
for item in Unidades:
    if item.numero not in unidad_in:
        try:
            print(item)
            session.add(item)
            session.commit()
        except:
            session.rollback()
            print('duplicado')
            continue
    session.close()

# %%
load_dataframe_Canbus(files_parsed)

# %%
#path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"
#path_engine = "firebird://sysdba:300184rm2@206.81.11.212///var/lib/firebird/3.0/data/SensoresRomaga.fdb"
engine = create_engine(path_engine, echo=True, future=False)
cores=3

Session = sessionmaker(bind=engine)
session = Session()

start_time=time.time()

unidades=[unidad for unidad in session.query(Unidad).all()]
files_parsed_list=[]

for unidad in unidades:
    unidad_in = session.query(Unidad).filter(Unidad.economico==unidad.economico).one()
    unidad_in.get_files()
    print('Unidad es {}'.format(unidad.economico))
    endtime_unit=time.time()
    files_parsed_list.append(unidad_in.parse_files())
        
try:
    with mp.Pool(processes=cores) as pool:
        func = partial(load_dataframe_litros,path_engine)
        DatframeList=pool.map(func,files_parsed_list)

    with mp.Pool(processes=cores) as pool:
        func = partial(load_dataframe_Canbus,path_engine)
        DatframeList=pool.map(func,files_parsed_list)
    print("*****************************")
    print("Tiempo totoal de ejecucion {}".format(time.time()-endtime_unit))

except:
    print('duplicado {}'.format(unidad.economico))
    raise

endpoint=start_time-time.time()    
print('Full units time {}'.format(endpoint))
session.close()
# Out:
# 2021-11-01 01:10:21,221 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:21,227 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# 2021-11-01 01:10:21,229 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00241s] ()
# 2021-11-01 01:10:21,533 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-01 01:10:21,535 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00235s] ('Eco01',)
# 2021-11-01 01:10:21,737 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-01 01:10:21,741 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00352s] ()
# 2021-11-01 01:10:22,098 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-01 01:10:22,101 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00316s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7fa7c456dc40>
# Not file in Abril2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa7c456d8b0>
# Not file in Enero2021 Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa791f162b0>
# Not file in Febrero2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa792f9ddf0>
# file in eventos Marzo2021Eco01.xlsx
# Eventos
# Marzo2021Eco01.xlsx
# Not file in Marzo2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa791e03cd0>
# file in eventos Mayo2021Eco01.xlsx
# Eventos
# Mayo2021Eco01.xlsx
# Not file in Mayo2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa79325b280>
# Not file in Junio2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa791d71be0>
# Not file in Julio2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7fa791dd3700>
# Not file in Agosto2021Eco01.xlsx
# Unidad es Eco01
# parse
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# File loaded ....../home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx typo de archivo cuentalitros
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# File loaded ....../home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx typo de archivo cuentalitros
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# File loaded ....../home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx typo de archivo cuentalitros_detalle
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# File loaded ....../home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx typo de archivo cuentalitros_detalle
# end load files
# 2021-11-01 01:10:48,241 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-01 01:10:48,247 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00599s] ()
# Start Query block
# 2021-11-01 01:10:48,811 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:48,813 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00207s] (Timestamp('2021-03-01 00:40:03'), '232.0', '279.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:49,014 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:49,121 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:49,126 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:49,129 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00263s] (Timestamp('2021-03-01 01:40:03'), '232.0', '278.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:49,416 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:49,520 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:49,527 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:49,531 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00391s] (Timestamp('2021-03-01 02:40:03'), '232.0', '278.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:49,825 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:49,930 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:49,936 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:49,939 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00359s] (Timestamp('2021-03-01 03:40:03'), '231.0', '278.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:50,233 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:50,336 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:50,341 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:50,343 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00265s] (Timestamp('2021-03-01 04:40:03'), '232.0', '278.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:50,636 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:50,738 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:50,743 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:50,746 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00301s] (Timestamp('2021-03-01 05:24:18'), '232.0', '278.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:51,039 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:51,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:51,151 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:51,153 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00247s] (Timestamp('2021-03-01 06:00:21'), '232.0', '277.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:51,440 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:51,543 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:51,547 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:51,549 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00237s] (Timestamp('2021-03-01 06:00:30'), '232.0', '277.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:51,840 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:51,948 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:51,955 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:51,958 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00353s] (Timestamp('2021-03-01 06:03:08'), '231.0', '275.0', '96858', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:52,251 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:52,358 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:52,364 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:52,367 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00364s] (Timestamp('2021-03-01 06:09:08'), '228.0', '273.0', '96861', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:52,659 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:52,767 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:52,772 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:52,775 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00359s] (Timestamp('2021-03-01 06:15:08'), '228.0', '276.0', '96863', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:53,067 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:53,173 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:53,180 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:53,183 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00347s] (Timestamp('2021-03-01 06:20:48'), '229.0', '279.0', '96865', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:53,477 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:53,585 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:53,590 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:53,592 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00285s] (Timestamp('2021-03-01 06:26:48'), '221.0', '276.0', '96868', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:53,883 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:53,986 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:53,991 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:53,994 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00300s] (Timestamp('2021-03-01 06:32:48'), '214.0', '283.0', '96871', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:54,284 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:54,385 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:54,391 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:54,395 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00365s] (Timestamp('2021-03-01 06:38:48'), '218.0', '277.0', '96877', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:54,682 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:54,786 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:54,790 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:54,792 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00245s] (Timestamp('2021-03-01 06:44:48'), '214.0', '279.0', '96882', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:55,088 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:55,194 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:55,201 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:55,204 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00358s] (Timestamp('2021-03-01 06:50:48'), '210.0', '284.0', '96886', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:55,504 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:55,610 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:55,614 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:55,618 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00404s] (Timestamp('2021-03-01 06:52:29'), '217.0', '271.0', '96888', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:55,913 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:56,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:56,021 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:56,024 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00292s] (Timestamp('2021-03-01 06:58:29'), '208.0', '279.0', '96892', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:56,315 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:56,415 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:56,418 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:56,420 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00203s] (Timestamp('2021-03-01 07:04:29'), '205.0', '273.0', '96896', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:56,709 INFO sqlalchemy.engine.Engine COMMIT
# cargados 100*n registros 20
# 2021-11-01 01:10:56,813 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:56,821 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:56,825 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00458s] (Timestamp('2021-03-01 07:10:29'), '210.0', '270.0', '96902', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:57,119 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:57,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:57,235 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:57,239 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00387s] (Timestamp('2021-03-01 07:16:29'), '209.0', '274.0', '96908', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:57,527 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:57,630 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:57,634 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:57,636 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00280s] (Timestamp('2021-03-01 07:22:29'), '205.0', '274.0', '96913', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:57,927 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:58,030 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:58,035 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:58,039 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00399s] (Timestamp('2021-03-01 07:28:29'), '206.0', '273.0', '96915', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:58,333 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:58,439 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:58,444 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:58,447 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00267s] (Timestamp('2021-03-01 07:30:45'), '199.0', '267.0', '96916', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:58,741 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:58,852 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:58,859 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:58,862 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00370s] (Timestamp('2021-03-01 07:36:45'), '203.0', '272.0', '96918', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:59,160 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:59,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:59,268 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:59,271 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00304s] (Timestamp('2021-03-01 07:38:59'), '206.0', '271.0', '96919', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:59,561 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:10:59,668 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:10:59,674 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:10:59,678 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00381s] (Timestamp('2021-03-01 07:50:39'), '212.0', '265.0', '96919', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:10:59,980 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:00,089 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:00,095 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:00,098 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00358s] (Timestamp('2021-03-01 07:50:49'), '212.0', '265.0', '96919', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:00,389 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:00,494 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:00,499 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:00,503 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00477s] (Timestamp('2021-03-01 07:56:49'), '209.0', '269.0', '96919', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:00,794 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:00,905 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:00,910 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:00,915 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00548s] (Timestamp('2021-03-01 08:02:49'), '206.0', '263.0', '96924', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:01,208 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:01,317 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:01,323 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:01,327 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00424s] (Timestamp('2021-03-01 08:08:49'), '206.0', '262.0', '96932', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:01,621 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:01,729 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:01,733 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:01,735 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00211s] (Timestamp('2021-03-01 08:14:31'), '205.0', '261.0', '96940', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:02,033 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:02,141 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:02,147 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:02,151 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00432s] (Timestamp('2021-03-01 08:19:05'), '199.0', '260.0', '96944', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:02,442 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:02,547 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:02,551 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:02,554 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00316s] (Timestamp('2021-03-01 08:25:05'), '191.0', '259.0', '96950', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:02,849 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:02,957 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:02,961 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:02,964 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00292s] (Timestamp('2021-03-01 08:31:05'), '190.0', '261.0', '96953', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:03,257 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:03,365 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:03,369 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:03,371 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00258s] (Timestamp('2021-03-01 08:32:15'), '191.0', '260.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:03,662 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:03,764 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:03,770 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:03,775 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00562s] (Timestamp('2021-03-01 09:32:15'), '215.0', '243.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:04,071 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:04,175 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:04,182 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:04,185 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00353s] (Timestamp('2021-03-01 09:34:44'), '215.0', '243.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:04,478 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:04,583 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:04,588 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:04,590 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00282s] (Timestamp('2021-03-01 09:40:44'), '215.0', '242.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:04,879 INFO sqlalchemy.engine.Engine COMMIT
# cargados 100*n registros 40
# 2021-11-01 01:11:04,982 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:04,986 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:04,989 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00319s] (Timestamp('2021-03-01 09:46:44'), '215.0', '242.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:05,280 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:05,380 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:05,386 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:05,389 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00379s] (Timestamp('2021-03-01 09:52:44'), '215.0', '242.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:05,695 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:05,801 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:05,809 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:05,811 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00306s] (Timestamp('2021-03-01 09:56:38'), '215.0', '242.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:06,108 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:06,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:06,215 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:06,217 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00216s] (Timestamp('2021-03-01 10:00:29'), '216.0', '230.0', '96954', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:06,510 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:06,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:06,619 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:06,621 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00278s] (Timestamp('2021-03-01 10:06:29'), '217.0', '235.0', '96956', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:06,916 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:07,023 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:07,027 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:07,031 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00434s] (Timestamp('2021-03-01 10:12:29'), '211.0', '241.0', '96958', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:07,325 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:07,432 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:07,439 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:07,442 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00407s] (Timestamp('2021-03-01 10:18:29'), '211.0', '240.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:07,736 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:07,840 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:07,844 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:07,846 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00272s] (Timestamp('2021-03-01 10:18:49'), '211.0', '237.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:08,138 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:08,242 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:08,246 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:08,249 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00260s] (Timestamp('2021-03-01 10:24:49'), '199.0', '251.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:08,547 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:08,649 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:08,654 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:08,657 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00268s] (Timestamp('2021-03-01 10:30:49'), '189.0', '260.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:08,943 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:09,051 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:09,059 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:09,063 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00343s] (Timestamp('2021-03-01 10:36:49'), '180.0', '269.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:09,352 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:09,457 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:09,461 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:09,463 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00258s] (Timestamp('2021-03-01 10:42:49'), '173.0', '275.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:09,756 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:09,860 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:09,865 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:09,867 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00287s] (Timestamp('2021-03-01 10:48:49'), '168.0', '280.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:10,156 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:10,258 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:10,262 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:10,264 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00265s] (Timestamp('2021-03-01 10:54:49'), '163.0', '285.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:10,556 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:10,657 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:10,661 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:10,664 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00297s] (Timestamp('2021-03-01 11:00:49'), '159.0', '288.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:10,954 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:11,056 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:11,061 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:11,064 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00294s] (Timestamp('2021-03-01 11:06:49'), '156.0', '291.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:11,352 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:11,455 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:11,462 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:11,464 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00307s] (Timestamp('2021-03-01 11:12:49'), '153.0', '294.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:11,755 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:11,857 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:11,861 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:11,864 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00285s] (Timestamp('2021-03-01 11:18:49'), '151.0', '296.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:12,157 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:12,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:12,267 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:12,270 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00252s] (Timestamp('2021-03-01 11:24:49'), '149.0', '297.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:12,563 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:12,666 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:12,671 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:12,674 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00358s] (Timestamp('2021-03-01 11:30:49'), '148.0', '298.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:12,966 INFO sqlalchemy.engine.Engine COMMIT
# cargados 100*n registros 60
# 2021-11-01 01:11:13,066 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:13,070 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:13,072 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00252s] (Timestamp('2021-03-01 11:36:49'), '147.0', '299.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:13,370 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:13,472 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:13,475 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:13,478 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00244s] (Timestamp('2021-03-01 11:42:49'), '146.0', '300.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:13,768 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:13,870 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:13,874 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:13,878 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00359s] (Timestamp('2021-03-01 11:48:49'), '145.0', '301.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:14,174 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:14,277 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:14,281 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:14,291 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.01027s] (Timestamp('2021-03-01 11:54:49'), '143.0', '302.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:14,579 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:14,679 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:14,683 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:14,686 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00278s] (Timestamp('2021-03-01 12:00:49'), '143.0', '302.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:14,977 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:15,079 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:15,084 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:15,086 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00271s] (Timestamp('2021-03-01 12:06:49'), '142.0', '303.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:15,378 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:15,479 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:15,484 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:15,487 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00265s] (Timestamp('2021-03-01 12:12:49'), '141.0', '303.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:15,799 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:15,905 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:15,912 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:15,915 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00321s] (Timestamp('2021-03-01 12:18:49'), '141.0', '303.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:16,211 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:16,319 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:16,323 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:16,325 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00274s] (Timestamp('2021-03-01 12:24:49'), '140.0', '304.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:16,616 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:16,719 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:16,725 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:16,728 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00276s] (Timestamp('2021-03-01 12:30:49'), '140.0', '304.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:17,023 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:17,124 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:17,128 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:17,131 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00336s] (Timestamp('2021-03-01 12:36:49'), '140.0', '304.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:17,429 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:17,531 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:17,535 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:11:17,537 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00249s] (Timestamp('2021-03-01 12:42:49'), '139.0', '304.0', '96959', 'Marzo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Marzo2021Eco01.xlsx', 1)
# 2021-11-01 01:11:17,836 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:11:17,940 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:11:17,943 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# ...
# 2021-11-01 01:35:50,903 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00233s] (Timestamp('2021-05-03 05:02:46'), '208.0', '338.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:51,196 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:51,299 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:51,302 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:51,304 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00209s] (Timestamp('2021-05-03 06:02:46'), '207.0', '338.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:51,602 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:51,708 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:51,711 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:51,713 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00218s] (Timestamp('2021-05-03 07:02:46'), '207.0', '338.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:52,004 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:52,107 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:52,110 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:52,112 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00209s] (Timestamp('2021-05-03 08:02:46'), '206.0', '338.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:52,402 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:52,521 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:52,525 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:52,526 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00208s] (Timestamp('2021-05-03 09:02:46'), '206.0', '340.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:52,831 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:52,935 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:52,939 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:52,941 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00213s] (Timestamp('2021-05-03 10:02:46'), '206.0', '341.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:53,233 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:53,335 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:53,339 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:53,341 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00221s] (Timestamp('2021-05-03 11:02:46'), '206.0', '342.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:53,652 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:53,758 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:53,762 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:53,764 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00219s] (Timestamp('2021-05-03 12:02:46'), '206.0', '342.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:54,060 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:54,160 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:54,164 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:54,166 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00213s] (Timestamp('2021-05-03 13:02:46'), '206.0', '343.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:54,454 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:54,556 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:54,559 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:54,561 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00223s] (Timestamp('2021-05-03 14:02:46'), '206.0', '343.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:54,882 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:54,985 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:54,988 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:54,990 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00204s] (Timestamp('2021-05-03 15:02:46'), '206.0', '343.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:55,286 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:55,386 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:55,389 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:55,391 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00211s] (Timestamp('2021-05-03 16:02:46'), '206.0', '343.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:55,684 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:55,786 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:55,790 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:55,792 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00218s] (Timestamp('2021-05-03 17:02:46'), '206.0', '343.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:56,078 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:56,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:56,181 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:56,183 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00212s] (Timestamp('2021-05-03 18:02:46'), '206.0', '343.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:56,471 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:56,572 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:56,576 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:56,578 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00219s] (Timestamp('2021-05-03 19:02:46'), '206.0', '342.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:56,873 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:56,977 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:56,981 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:56,984 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00312s] (Timestamp('2021-05-03 20:02:20'), '206.0', '342.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:57,275 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:57,377 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:57,381 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:57,383 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00212s] (Timestamp('2021-05-03 20:02:30'), '206.0', '342.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:57,675 INFO sqlalchemy.engine.Engine COMMIT
# cargados 100*n registros 140
# 2021-11-01 01:35:57,776 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:57,779 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:57,781 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00217s] (Timestamp('2021-05-03 20:08:30'), '208.0', '338.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:58,070 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:58,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:58,173 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:58,175 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00222s] (Timestamp('2021-05-03 20:14:30'), '200.0', '346.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:58,466 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:58,566 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:58,569 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:58,571 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00217s] (Timestamp('2021-05-03 20:20:30'), '189.0', '356.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:58,859 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:58,959 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:58,963 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:58,965 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00224s] (Timestamp('2021-05-03 20:26:30'), '179.0', '366.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:59,253 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:59,354 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:59,358 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:59,360 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00251s] (Timestamp('2021-05-03 20:31:06'), '173.0', '372.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:35:59,649 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:35:59,749 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:35:59,753 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:35:59,755 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00213s] (Timestamp('2021-05-03 21:31:06'), '164.0', '381.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:36:00,044 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:36:00,146 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:36:00,150 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:36:00,154 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00384s] (Timestamp('2021-05-03 22:31:06'), '164.0', '381.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:36:00,446 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:36:00,552 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:36:00,556 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:36:00,558 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00206s] (Timestamp('2021-05-03 23:31:06'), '163.0', '382.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:36:00,850 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:36:00,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:36:00,954 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)
# 2021-11-01 01:36:00,956 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00212s] (Timestamp('2021-05-04 00:31:06'), '163.0', '382.0', '101204', 'Mayo2021Eco01.xlsx', '/home/rokdrigo/GitClone/Combustible2/Sensores/Mayo2021Eco01.xlsx', 1)
# 2021-11-01 01:36:01,247 INFO sqlalchemy.engine.Engine COMMIT
# 2021-11-01 01:36:01,348 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-01 01:36:01,351 INFO sqlalchemy.engine.Engine INSERT INTO "Sensores_table" ("Fecha_Hora", "Tanque 1 (Lt)", "Tanque 2 (Lt)", "Odómetro (Km)", file_name, "file", unidad_id) VALUES (?, ?, ?, ?, ?, ?, ?)

# %%
#path_engine='sqlite:////home/rokdrigo/GitClone/Combustible2/Sensores/sqlalchemy.db'
path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"

cnx = create_engine(path_engine).connect()
  
# table named 'contacts' will be returned as a dataframe.
tables=['Sensores_canbus', 'Sensores_table', 'Unidades']

df1 = pd.read_sql_query('SELECT * FROM \"Sensores_table\" ', cnx,coerce_float=False)
df2 =pd.read_sql_table('Sensores_canbus',cnx)

# %%
for item in session.query(SensoresCanbus.canbus).group_by(SensoresCanbus.file_name).all():
    print(item)

# %%
from sqlalchemy import Column, Integer, String,Boolean, ForeignKey,UniqueConstraint,PrimaryKeyConstraint,sql
from sqlalchemy.orm import declarative_base,sessionmaker,relationship
from sqlalchemy import *
from sqlalchemy import event,DDL,Sequence,Identity
import pandas as pd
import os
import fnmatch
import re
import multiprocessing as mp
import xlrd
import pickle
import time
from readExcelFiles import *
from openpyxl import load_workbook

path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"
path_to_files="/home/rokdrigo/GitClone/Combustible2/Sensores/"

engine = create_engine(path_engine, echo=True, future=True)
qs="DROP TRIGGER Unidades_BI"
qs2="DROP GENERATOR gen_Unidades_id;"
qs3="DROP TABLE \"Sensores_canbus\""
qs4="DROP TABLE \"Unidades\""
qs5="DROP TABLE \"Sensores_table\""
qC="SELECT * FROM \"Sensores_table\""
Session = sessionmaker(engine)

with engine.connect() as conn:
    #result = conn.execute(text(qs))
    #result = conn.execute(text(qs2))
    #onn.execute(text(qs3))
    #nn.commit()
    #onn.execute(text(qs5))
    #conn.commit()
    conn.execute(text(qs4))
    conn.commit()

    #result = conn.execute(text(qC))
    
conn.close()

# %%
from firebird.driver import connect, driver_config,create_database

driver_config.read('myapp.cfg')

qs="DROP TRIGGER Unidades_BI"
qs2="DROP GENERATOR gen_Unidades_id;"
qs3="DROP TABLE \"Sensores_canbus\""
qs4="DROP TABLE \"Unidades\""
qs5="DROP TABLE \"Sensores_table\""

#qC="SELECT * FROM \"Sensores_table\""

with connect('firbirdSensores') as con:
    cur = con.cursor()
    cur.execute(qs3)
    cur.execute(qs5)
    cur.execute(qs4)
    con.commit()

# %%
1520/60
