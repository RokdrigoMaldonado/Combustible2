# %%
from sqlalchemy import Column, Integer, String,Boolean, ForeignKey,UniqueConstraint,PrimaryKeyConstraint,sql
from sqlalchemy.orm import declarative_base,sessionmaker,relationship,configure_mappers
from sqlalchemy.inspection import inspect
from sqlalchemy import *
from sqlalchemy import event,Sequence,Identity
import pandas as pd
import os
import fnmatch
import re
import multiprocessing as mp
import xlrd
import pickle
import time
from readExcelFiles import *
from queryblock import *
from MultiORM import *
from openpyxl import load_workbook
from functools import partial
from models import *
# Out:
# Traceback (most recent call last):
#
#   File "/home/rokdrigo/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-3-268a7bb1cc2d>", line 16, in <module>
#     from MultiORM import *
#
#   File "/home/rokdrigo/GitClone/Combustible2/MultiORM.py", line 13
#     from
#          ^
# SyntaxError: invalid syntax

# %%
#load_dataframe_litros(files_parsed)
path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"

engine = create_engine(path_engine, echo=False, future=False)

Session = sessionmaker(bind=engine)
session = Session()

for item in session.query(SensoresCanbus).all():
    print(item.file)

# %%
load_dataframe_Canbus(files_parsed)

# %%
# Out:
# 2021-11-02 19:06:41,805 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2021-11-02 19:06:41,820 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# 2021-11-02 19:06:41,834 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.01479s] ()
# 2021-11-02 19:06:41,865 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:06:41,877 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.01164s] ('Eco01',)
# 2021-11-02 19:06:41,907 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:06:41,915 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00307s] ()
# 2021-11-02 19:07:18,638 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:07:18,641 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00321s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f58abbd07f0>
# Not file in Abril2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f58abbd0760>
# Not file in Enero2021 Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba0a60>
# Not file in Febrero2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba80d0>
# Not file in Marzo2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ec60430>
# Not file in Mayo2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ec78d60>
# Not file in Junio2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba8250>
# Not file in Julio2021Eco01.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f58ab8d9f70>
# Not file in Agosto2021Eco01.xlsx
# Unidad es Eco01
# Nothing
# 2021-11-02 19:07:48,272 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:07:48,274 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00207s] ('Eco05',)
# 2021-11-02 19:07:48,282 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:07:48,284 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00209s] ()
# 2021-11-02 19:08:27,187 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:08:27,189 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00212s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e895e20>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eb5f520>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e89a190>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e89acd0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e8ecfd0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e9fc4f0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e9fc340>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e6fd250>
# Unidad es Eco05
# Nothing
# 2021-11-02 19:08:56,138 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:08:56,140 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00190s] ('Eco07',)
# 2021-11-02 19:08:56,148 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:08:56,158 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.01043s] ()
# 2021-11-02 19:09:33,791 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:09:33,794 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00220s] ()
# Unidad es Eco07
# Nothing
# 2021-11-02 19:10:00,466 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:10:00,467 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00205s] ('Eco08',)
# 2021-11-02 19:10:00,480 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:10:00,482 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00203s] ()
# 2021-11-02 19:10:38,226 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:10:38,228 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00191s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e7022e0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e791b50>
# <openpyxl.workbook.workbook.Workbook object at 0x7f58ab8c9dc0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e8ecb50>
# <openpyxl.workbook.workbook.Workbook object at 0x7f58ab8c5730>
# <openpyxl.workbook.workbook.Workbook object at 0x7f58abbf0880>
# <openpyxl.workbook.workbook.Workbook object at 0x7f58abbf0280>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e6bce80>
# Unidad es Eco08
# Nothing
# 2021-11-02 19:11:07,134 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:11:07,136 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00200s] ('Eco09',)
# 2021-11-02 19:11:07,145 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:11:07,147 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00202s] ()
# 2021-11-02 19:11:43,907 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:11:43,910 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00281s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e7db100>
# <openpyxl.workbook.workbook.Workbook object at 0x7f58ab8ccee0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e7db2b0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f58ab8d9f70>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ec789a0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ea585e0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e9f1790>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e9f10a0>
# Unidad es Eco09
# Nothing
# 2021-11-02 19:12:10,840 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:12:10,842 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00192s] ('Eco10',)
# 2021-11-02 19:12:10,851 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:12:10,853 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00204s] ()
# 2021-11-02 19:12:49,825 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:12:49,836 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.01119s] ()
# Unidad es Eco10
# Nothing
# 2021-11-02 19:13:18,217 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:13:18,219 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00214s] ('Eco11',)
# 2021-11-02 19:13:18,227 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:13:18,229 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00224s] ()
# 2021-11-02 19:13:57,281 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:13:57,283 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00267s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e7647c0>
# Not file in Junio2021Eco11.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e775ee0>
# Not file in Julio2021Eco11.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ea82df0>
# Not file in Agosto2021Eco11.xlsx
# Unidad es Eco11
# Nothing
# 2021-11-02 19:14:25,624 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:14:25,627 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00284s] ('Eco12',)
# 2021-11-02 19:14:25,639 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:14:25,641 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00261s] ()
# 2021-11-02 19:15:04,623 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:15:04,625 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00295s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ea58580>
# Not file in Abril2021Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eb160d0>
# Not file in Enero2021 Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e775ac0>
# Not file in Febrero2021Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e618790>
# Not file in Marzo2021Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e525910>
# Not file in Mayo2021Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e5bf5b0>
# Not file in Junio2021Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e618eb0>
# Not file in Julio2021Eco12.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e4b47f0>
# Not file in Agosto2021Eco12.xlsx
# Unidad es Eco12
# Nothing
# 2021-11-02 19:15:31,871 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:15:31,873 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00202s] ('Eco13',)
# 2021-11-02 19:15:31,890 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:15:31,892 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00218s] ()
# 2021-11-02 19:16:10,497 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:16:10,499 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00192s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e6844c0>
# Not file in Abril2021Eco13.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e684820>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e487940>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e775c10>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e45b130>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e684d30>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e58c520>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e3f7e80>
# Unidad es Eco13
# Nothing
# 2021-11-02 19:16:38,240 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:16:38,242 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00195s] ('Eco14',)
# 2021-11-02 19:16:38,251 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:16:38,253 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00229s] ()
# 2021-11-02 19:17:16,172 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:17:16,174 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00270s] ()
# Unidad es Eco14
# Nothing
# 2021-11-02 19:17:42,266 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:17:42,269 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00298s] ('Eco15',)
# 2021-11-02 19:17:42,282 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:17:42,285 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00287s] ()
# 2021-11-02 19:18:19,919 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:18:19,920 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00192s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e361eb0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e58c7c0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e52af40>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e30e8b0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e30ea30>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e4359a0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e43e700>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e4359d0>
# Not file in Agosto2021Eco15.xlsx
# Unidad es Eco15
# Nothing
# 2021-11-02 19:18:47,991 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:18:47,993 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00221s] ('Eco16',)
# 2021-11-02 19:18:48,005 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:18:48,009 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00427s] ()
# 2021-11-02 19:19:25,103 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:19:25,105 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00241s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e30eac0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba10d0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba1220>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588ffd89a0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e89abb0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e33dd60>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e33d9a0>
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e775850>
# Unidad es Eco16
# Nothing
# 2021-11-02 19:19:53,511 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:19:53,513 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00195s] ('Eco17',)
# 2021-11-02 19:19:53,532 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:19:53,534 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00235s] ()
# 2021-11-02 19:20:30,014 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:20:30,016 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00209s] ()
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e684220>
# Not file in Abril2021Eco17.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e96de50>
# Not file in Marzo2021Eco17.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba0cd0>
# Not file in Mayo2021Eco17.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588e7028b0>
# Not file in Junio2021Eco17.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f58ab8dcd60>
# Not file in Julio2021Eco17.xlsx
# <openpyxl.workbook.workbook.Workbook object at 0x7f588eba0d30>
# Not file in Agosto2021Eco17.xlsx
# Unidad es Eco17
# Nothing
# 2021-11-02 19:20:58,255 INFO sqlalchemy.engine.Engine SELECT "Unidades".numero AS "Unidades_numero", "Unidades".economico AS "Unidades_economico", "Unidades".canbus AS "Unidades_canbus", "Unidades".company AS "Unidades_company"
# FROM "Unidades"
# WHERE "Unidades".economico = ?
# 2021-11-02 19:20:58,257 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00251s] ('Eco18',)
# 2021-11-02 19:20:58,267 INFO sqlalchemy.engine.Engine SELECT "Sensores_table".file_name AS "Sensores_table_file_name"
# FROM "Sensores_table" GROUP BY "Sensores_table".file_name
# 2021-11-02 19:20:58,269 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00238s] ()
# 2021-11-02 19:21:35,631 INFO sqlalchemy.engine.Engine SELECT "Sensores_canbus".file_name AS "Sensores_canbus_file_name"
# FROM "Sensores_canbus" GROUP BY "Sensores_canbus".file_name
# 2021-11-02 19:21:35,633 INFO sqlalchemy.engine.Engine [dialect firebird+fdb does not support caching 0.00280s] ()
# Unidad es Eco18
# Nothing
# NoneNoneNone
#
#
# None
# NoneNoneNone
#
# None
# None
# None
#
# NoneNoneNone
#
# None
#
# NoneNone
# None
# Start Canbus PASSSSS.................................................
#
# Start Canbus PASSSSS.................................................
# NoneStart Canbus PASSSSS.................................................
# None
# None
# Start Canbus PASSSSS.................................................
#
# NoneStart Canbus PASSSSS.................................................
# Start Canbus PASSSSS.................................................
#
# Start Canbus PASSSSS.................................................
# duplicado Eco18
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/rokdrigo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/rokdrigo/anaconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/rokdrigo/GitClone/Combustible2/MultiORM.py", line 50, in load_dataframe_Canbus
#     loadeded=[item[0] for item in session.query(SensoresCanbus.file_name).group_by(SensoresCanbus.file_name).all()]
# NameError: name 'session' is not defined
# """
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-92a2e4880312> in <module>
#      28     with mp.Pool(processes=cores) as pool:
#      29         func = partial(load_dataframe_Canbus,path_engine)
# ---> 30         DatframeList=pool.map(func,files_parsed_list)
#      31     print("*****************************")
#      32     print("Tiempo totoal de ejecucion {}".format(time.time()-endtime_unit))
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# NameError: name 'session' is not defined

# %%
#path_engine='sqlite:////home/rokdrigo/GitClone/Combustible2/Sensores/sqlalchemy.db'
path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"

cnx = create_engine(path_engine).connect()
  
# table named 'contacts' will be returned as a dataframe.
tables=['Sensores_canbus', 'Sensores_table', 'Unidades']

df1 = pd.read_sql_query('SELECT * FROM \"Sensores_table\" ', cnx,coerce_float=False)
df2 =pd.read_sql_table('Sensores_canbus',cnx)

# %%
for item in session.query(SensoresCanbus.canbus).group_by(SensoresCanbus.file_name).all():
    print(item)

# %%
from sqlalchemy import Column, Integer, String,Boolean, ForeignKey,UniqueConstraint,PrimaryKeyConstraint,sql
from sqlalchemy.orm import declarative_base,sessionmaker,relationship
from sqlalchemy import *
from sqlalchemy import event,DDL,Sequence,Identity
import pandas as pd
import os
import fnmatch
import re
import multiprocessing as mp
import xlrd
import pickle
import time
from readExcelFiles import *
from openpyxl import load_workbook

path_engine = "firebird://sysdba:300184rm2@localhost///home/rokdrigo/GitClone/Combustible2/firebirdDatabase/firbirdSensores.fdb"
path_to_files="/home/rokdrigo/GitClone/Combustible2/Sensores/"

engine = create_engine(path_engine, echo=True, future=True)
qs="DROP TRIGGER Unidades_BI"
qs2="DROP GENERATOR gen_Unidades_id;"
qs3="DROP TABLE \"Sensores_canbus\""
qs4="DROP TABLE \"Unidades\""
qs5="DROP TABLE \"Sensores_table\""
qC="SELECT * FROM \"Sensores_table\""
Session = sessionmaker(engine)

with engine.connect() as conn:
    #result = conn.execute(text(qs))
    #result = conn.execute(text(qs2))
    #onn.execute(text(qs3))
    #nn.commit()
    #onn.execute(text(qs5))
    #conn.commit()
    conn.execute(text(qs4))
    conn.commit()

    #result = conn.execute(text(qC))
    
conn.close()

# %%
from firebird.driver import connect, driver_config,create_database

driver_config.read('myapp.cfg')

qs="DROP TRIGGER Unidades_BI"
qs2="DROP GENERATOR gen_Unidades_id;"
qs3="DROP TABLE \"Sensores_canbus\""
qs4="DROP TABLE \"Unidades\""
qs5="DROP TABLE \"Sensores_table\""

#qC="SELECT * FROM \"Sensores_table\""

with connect('firbirdSensores') as con:
    cur = con.cursor()
    cur.execute(qs3)
    cur.execute(qs5)
    cur.execute(qs4)
    con.commit()

# %%
1520/60
